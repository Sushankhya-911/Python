# %% [markdown]
# # VARIABLES

# %%
- VARIABLE TERM VARY(VALUES WILL VARY)
- WE WANT TO TO SAVE SOME VALUES AT SOME PLACE ,THAT PLACE IS CALLED VARIABLES
- VARIABLES AND CONSTANT

# %%
NUMBER=100 #100 VALUE IS STORED IN VARIABLE CALLED NUMBER
NUMBER #SO HERE NUMBER IS A VARIABLE
# Out:
# 100

# %%
NUMBER=200
NUMBER
# Out:
# 200

# %%
# SO HERE 1ST NUMBER HAS 100 AND 2ND NUMBER HAS 200 .SO,NUMBER IS CHANGINIG
#SO,WE ARE CALLING NUMBER AS  A VARIABLE.

# %% [markdown]
# **RULES TO DEFINE VARIABLES**

# %%
#lower case
number=400
number
# Out:
# 400

# %%
# Combination of lower case and Upper case
nuMBer=500
nuMBer
# Out:
# 500

# %%
#sum
sum=700
sum
# Out:
# 700

# %% [markdown]
# **Note**:
#   - sum is a math operation it will works
#   - but do not use as variable
#   - after some time the python will be confuse ,so dont use this

# %%
#Combination of number and letters ,numbers as suffix
number123=300
number123
# Out:
# 300

# %%
#underscore
number_=900
number_
# Out:
# 900

# %%
#only underscope
_=90
_
# Out:
# 90

# %% [markdown]
# **FAILED CASES**

# %%
#Special characters 
number% =500
number%
# Out:
#   Cell In[25], line 2
#     number% =500
#             ^
# SyntaxError: invalid syntax

# %%
# Combination of letters an number ,numbers as prefix fails
123number=600
123number
# Out:
#   Cell In[38], line 2
#     123number=600
#       ^
# SyntaxError: invalid decimal literal

# %%
# if CASE
if =500
if
# Out:
#   Cell In[32], line 2
#     if =500
#        ^
# SyntaxError: invalid syntax

# %%
# space not allowed
number one=500
number one
# Out:
#   Cell In[42], line 2
#     number one=500
#            ^
# SyntaxError: invalid syntax
