# %% [markdown]
# **Type casting:**

# %% [markdown]
# - Change one data type to anothr dat type
# - int -------> float
# - int  "       string
# - int   "      boolean
# - int   "      complex
# - similarly with float,string,boolean,complex

# %% [markdown]
# $ integer $ $ to $ $other$ $ type $ $ of $ $data $

# %%
number1=100
number1
# Out:
# 100

# %%
type(number1)
# Out:
# int

# %% [markdown]
# **Case 1**

# %%
# case-1 : int===>float
float(number1) # number1 to float
# Out:
# 100.0

# %%
float_number=float(number1) #storing float number into variable

# %%
type(float_number)
# Out:
# float

# %% [markdown]
# **Case 2**

# %%
#case-2 :int===>string
number=10
number
# Out:
# 10

# %%
type(number)
# Out:
# int

# %%
str(number)
# Out:
# '10'

# %%
str_number=str(number)

# %%
type(str_number)
# Out:
# str

# %% [markdown]
# **Case 3**

# %%
#int ==> boolean

# %%
num=10
num
# Out:
# 10

# %%
type(num)
# Out:
# int

# %%
bool(num)
# Out:
# True

# %%
boolean=bool(num)

# %%
type(boolean)
# Out:
# bool

# %%
bool(0)
# Out:
# False

# %% [markdown]
# **Note : Other than zero every thing is False**

# %% [markdown]
# **Case-4**

# %%
#int ====>complex cojugate
a=100
a
# Out:
# 100

# %%
type(a)
# Out:
# int

# %%
complex(a)
# Out:
# (100+0j)

# %%
complex_76=complex(a)

# %%
type(complex_76)
# Out:
# complex

# %% [markdown]
# $ RESULTS $

# %% [markdown]
# - float_number=float(number) #100.0
# - string_number=str(number)#'100'
# - boolean_number=bool(number)#True
# - complex_conjugate=complex(number)# 100+0j

# %% [markdown]
# $ float $ $ to $ $another $ $ data $ $type$

# %% [markdown]
# **Case 1**

# %%
number_2=200.5
int_number2=int(number_2)
int_number2
# Out:
# 200

# %%
type(number_2)
# Out:
# float

# %%
type(int_number2)
# Out:
# int

# %% [markdown]
# **Case 2**

# %%
number_2=200.5
boolean_number=bool(number_2)
boolean_number
# Out:
# True

# %%
type(boolean_number)
# Out:
# bool

# %% [markdown]
# **Case 3**

# %%
number_2=200.5
string_number=str(number_2)
string_number
# Out:
# '200.5'

# %%
type(string_number)
# Out:
# str

# %% [markdown]
# **Case 4**

# %%
number_2=200.5
complex_conjugate=complex(number_2)
complex_conjugate
# Out:
# (200.5+0j)

# %%
type(complex_conjugate)
# Out:
# complex

# %% [markdown]
# $ string $ $ to$ $ other $ $type $ $ of $ $ data $

# %%
string_1="apple"
floatnumber=float(string_1)
floatnumber
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 2
#       1 string_1="apple"
# ----> 2 floatnumber=float(string_1)
#       3 floatnumber
#
# ValueError: could not convert string to float: 'apple'

# %%
type(floatnumber)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 type(floatnumber)
#
# NameError: name 'floatnumber' is not defined

# %% [markdown]
# **Note:The english alphabet doesnot respond in int,float,complex conjugate**

# %% [markdown]
# $ IMP $ $ CASE $

# %%
string_1="apple"
booleannumbr=bool(string_1)
booleannumbr
# Out:
# True

# %%
type(booleannumbr)
# Out:
# bool

# %% [markdown]
# **NOTE:**
# - In english alphabet the empty string will  only give false result
# - In math the 0 only give the false result

# %% [markdown]
# **Case-3**

# %%
string_value2="10.5"    # BASE TYPE IN FLOAT ==REPRESENT IN QUOTES
int(string_value2)      #ERROR
float(string-value2)     10.5
bool(string_value2)      True
complex(string_value2)   10.5+0j

# %% [markdown]
# **NOTE:**
# - if the base is of float then it will not work in int if represented in quotes?strings

# %%
string_value2="10"  # No error because base type is int 
int(string_value2)      10
float(string-value2)    10.0
bool(string_value2)     True
complex(string_value2)  10+0j

# %% [markdown]
# **1) Convert string to integer without error**
# - Where,string_1="10.5"
# - Ans =first convert into float then into integer

# %%
string_1=10.5
n1=float(string_1)
n2=int(n1)
n2
# Out:
# 10

# %% [markdown]
# $ boolean $ $ to $ $other $ $ type $ $ of $ $ data$

# %%
val1=True
int(val1)      1
float(val1)    1.0
str(float1)   'True'
complex(val1)   1+0j

# %%
val2=False
int(val2)     0
float(val2)   0.0
str(val2)     'False'
complex(val2) 0+0j

# %% [markdown]
# $complex $ $ to $ $ other $ $ type $ $ of $ $ data $

# %%
val3=100+0j
int(val3)    #error
float(val3)  #error
str(val3)    #'100+0j'
bool(val3)   #'True'

# %%
val3=100+0j
int(val3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 2
#       1 val3=100+0j
# ----> 2 int(val3)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
bool(0j)
# Out:
# False
