# %%
import random

i = 0
a = random.randint(0, 9)

while True:
    num = eval(input('Enter a number: '))
    print('Guess number: {}'.format(num))
    if num != a:
        print('Try again')
    else:
        print('You got it right! Congo!')
        break 
    i += 1
# Out:
# Enter a number:  2
# Guess number: 2
# Try again
# Enter a number:  3
# Guess number: 3
# Try again
# Enter a number:  7
# Guess number: 7
# Try again
# Enter a number:  4
# Guess number: 4
# Try again
# Enter a number:  5
# Guess number: 5
# Try again
# Enter a number:  6
# Guess number: 6
# Try again
# Enter a number:  8
# Guess number: 8
# Try again
# Enter a number:  1
# Guess number: 1
# Try again
# Enter a number:  9
# Guess number: 9
# Try again
# Enter a number:  0
# Guess number: 0
# You got it right! Congo!

# %%
import random

i = 0
a = random.randint(0, 9)
while True:
    num = eval(input('Enter a number: '))
    print('Guess number: {}'.format(num))
    if num != a:
        if num<a:
            print('Too low')
        if num>a:
            print('Too high')
    else:
        print('You got it right! Congo!')
    if i==2:   
        break 
    i += 1
# Out:
# Enter a number:  2
# Guess number: 2
# Too low
# Enter a number:  8
# Guess number: 8
# Too high
# Enter a number:  6
# Guess number: 6
# Too low
