# %%
num1=eval(input("enter a number:"))
num2=eval(input("enter a number:"))
add=num1+num2
print("Total number:",add)
# Out:
# enter a number: 10
# enter a number: 20
# Total number: 30

# %% [markdown]
# $ Types $ $ of $ $ error $

# %% [markdown]
# **Error-1**
# - Name error

# %%
num1=eval(input("enter a number:"))
num2=eval(input("enter a number:"))
add=num1+num3
print("Total number:",add)
# Out:
# enter a number: 10
# enter a number: 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 num1=eval(input("enter a number:"))
#       2 num2=eval(input("enter a number:"))
# ----> 3 add=num1+num3
#       4 print("Total number:",add)
#
# NameError: name 'num3' is not defined

# %% [markdown]
# **Error-2**
# - Syntax error

# %%
num1=eval(input("enter a number:"))
num2=eval(input("enter a number:")
add=num1+num2
print("Total number:",add)
# Out:
#   Cell In[31], line 2
#     num2=eval(input("enter a number:")
#              ^
# SyntaxError: '(' was never closed

# %% [markdown]
# **Error-3**
#
#  - Zero division error

# %%
num1=eval(input("enter a number:"))
num2=eval(input("enter a number:"))
divide=num1/num2
print("Total number:",divide)
# Out:
# enter a number: 100
# enter a number: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[34], line 3
#       1 num1=eval(input("enter a number:"))
#       2 num2=eval(input("enter a number:"))
# ----> 3 divide=num1/num2
#       4 print("Total number:",divide)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **Error-4**
#
# - Unsupported operand type

# %%
num1=input("enter a number:") # STRING
num2=eval(input("enter a number:")) #INT
add=num1/num2
print("Total number:",add)
# Out:
# enter a number: 10
# enter a number: 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 num1=input("enter a number:") # STRING
#       2 num2=eval(input("enter a number:")) #INT
# ----> 3 add=num1/num2
#       4 print("Total number:",add)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# **Error-5**
# - Missing parentheses

# %%
num1=eval(input("enter a number:")) 
num2=eval(input("enter a number:")) 
d=num1/num2
print Total number:",d
# Out:
#   Cell In[42], line 4
#     print Total number:",d
#                        ^
# SyntaxError: unterminated string literal (detected at line 4)

# %% [markdown]
# **Error-6**
# - Name error

# %%
num1=eval(input("enter a number:"))
num2=eval(input("enter a number:")) 
d=num1/num2
Print ("Total number:",d)
# Out:
# enter a number: 10
# enter a number: 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 4
#       2 num2=eval(input("enter a number:"))
#       3 d=num1/num2
# ----> 4 Print ("Total number:",d)
#
# NameError: name 'Print' is not defined

# %% [markdown]
# ### NOTE

# %% [markdown]
# - these are possible errors ,while doing assignments other different errors we  will learn

# %% [markdown]
# **Again**
#
# - Suppose we have to write 500 lines
# - but we got error in 200 line
# - in order to get rid out of that,we will be learning about something named,
#    $ Exception $ $ Handling $

# %% [markdown]
# $ Exception $ $ Handling $

# %% [markdown]
# **key words**
#   $ try $ & $ except $
# - there are two blocks
# - one is try blocks
# - second one is exception(except) block
# - our code will be there in try block
# - error capture will happens in except block
# - indentation : the space left between the inial word to column after you press enter
# - red : space/indentation not maintained properly
# - indentation has minimum 4 characters( 4 times space)
# - Or enter tab
# - : is there,then indentation will be there

# %%
try:num1=10#(It is inside try block)
    num2=20 #( ' ''   '    '    '   )
#num3=30 (It is not inside try block)

# %% [markdown]
# **NOTE:**
# - If error is there the statement we wrote in print  parentheses will work

# %% [markdown]
# $ Method $ - $ 1$

# %%
try:
    b=10
    c=20
    d=30
    a=b+c+d
    print(a)

except:
    print("error is there,check code")
# Out:
# 60

# %% [markdown]
# $ Method $ - $ 2 $

# %%
try:
    b=10
    c=0
    d=30
    a=b/c # 10/0---->undefined
    print(a)

except:
    print("error is there,check code")
# Out:
# error is there,check code

# %% [markdown]
# **WAP ask the user eter 3 numbers and find the average and also use try and except blocks**

# %%
num1=eval(input("enter a number-1:"))
num2=eval(input("enter a number-2:"))
num3=eval(input("enter a number-3:"))
average=(num1+num2+num3)/3
print("The avergae of {},{} and {} is {}".format(num1,num2,num3,average))
# Out:
# enter a number-1: 10
# enter a number-2: 20
# enter a number-3: 20
# The avergae of 10,20 and 20 is 16.666666666666668

# %% [markdown]
# $ Method $ -$ 1 $

# %%
try:
    num1=eval(input("enter a number-1:"))
    num2=eval(input("enter a number-2:"))
    num3=eval(input("enter a number-3:"))
    average=(num1+num2+num33)/3
    print("The avergae of {},{} and {} is {}".format(num1,num2,num3,average))

except:
    print("Error is there")
# Out:
# enter a number-1: 10
# enter a number-2: 20
# enter a number-3: 30
# Error is there

# %% [markdown]
# **But,we want to classify which error is there .SO( except Exception as e :)**

# %% [markdown]
# $ Error-classification-acc-to-error $

# %% [markdown]
# **1)**

# %%
try:
    num1=eval(input("enter a number-1:"))
    num2=eval(input("enter a number-2:"))
    num3=eval(input("enter a number-3:"))
    average=(num1+num2+num33)/3
    print("The avergae of {},{} and {} is {}".format(num1,num2,num3,average))

except Exception as e:
    print(e)
# Out:
# enter a number-1: 10
# enter a number-2: 20
# enter a number-3: 30
# name 'num33' is not defined

# %% [markdown]
# **2)**

# %%
try:
    num1=eval(input("enter a number-1:"))
    num2=eval(input("enter a number-2:"))
    num3=eval(input("enter a number-3:"))
    average=(num1+num2+num3)/0
    print("The avergae of {},{} and {} is {}".format(num1,num2,num3,average))

except Exception as e:
    print(e)
# Out:
# enter a number-1: 10
# enter a number-2: 320
# enter a number-3: 30
# division by zero

# %% [markdown]
# **3)**

# %%
try:
    num1=eval(input("enter a number-1:"))
    num2=eval(input("enter a number-2:"))
    num3=eval(input("enter a number-3:"))
    average=(num1+num2+num33)/3
    print("The avergae of {},{} and {} is {}".format(num1,num2,num3,average)

except Exception as e:
    print(e)
# Out:
#   Cell In[144], line 6
#     print("The avergae of {},{} and {} is {}".format(num1,num2,num3,average)
#          ^
# SyntaxError: '(' was never closed

# %%
try:
    print('hello)
# Out:
#   Cell In[146], line 2
#     print('hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# - If our code is with out error,try block will execute
# - If not ,it will redirect to except block
# - What ever you written inside except block that will run
# - Try and exception is together
# - Omnes try and exceptions code are complete,it try to look any other lines of code are there

# %%
print("Suti is donkey")
print("Suti says,1+1=0")
print("Hence,proved")

try:
    num1=eval(input("enter a number-1:"))
    num2=eval(input("enter a number-2:"))
    num3=eval(input("enter a number-3:"))
    average=(num1+num2+num33)/3
    print("The avergae of {},{} and {} is {}".format(num1,num2,num3,average))

except Exception as e:
    print(e)
# Out:
# Suti is donkey
# Suti says,1+1=0
# Hence,proved
# enter a number-1: 10
# enter a number-2: 20
# enter a number-3: 30
# name 'num33' is not defined
